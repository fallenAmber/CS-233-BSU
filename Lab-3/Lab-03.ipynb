# %% [markdown]
# ### Lab 3 - Plotting and Visualization

# %% [markdown]
# Name = Md Tohidul Islam

# %%
# import statements
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### 1. Upload the file *recent_grads.csv* into a `DataFrame` called `data`.
# * Change the index to the `Rank` column.
# * Display the first 5 rows of the data.

# %%
data = pd.read_csv('recent_grads.csv')

data.set_index('Rank', inplace=True)

data.head()
# Out:
#       Major_code                                      Major    Total      Men  \
# Rank
# 1           2419                      PETROLEUM ENGINEERING   2339.0   2057.0
# 2           2416             MINING AND MINERAL ENGINEERING    756.0    679.0
# 3           2415                  METALLURGICAL ENGINEERING    856.0    725.0
# 4           2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0   1123.0
# 5           2405                       CHEMICAL ENGINEERING  32260.0  21239.0
#
#         Women Major_category  ShareWomen  Sample_size  Employed  Full_time  \
# Rank
# 1       282.0    Engineering    0.120564           36      1976       1849
# 2        77.0    Engineering    0.101852            7       640        556
# 3       131.0    Engineering    0.153037            3       648        558
# 4       135.0    Engineering    0.107313           16       758       1069
# 5     11021.0    Engineering    0.341631          289     25694      23170
#
# ...

# %% [markdown]
# #### 2. Create a figure that holds a 2x1 matrix of subplots.
# * In the first subplot, plot the `P75th` column with a dashed, green line and titled 'Line Plot'.
# * In the second subplot, plot a histogram of the `Median` column with 50 bins and titled 'Histogram'.
# * Adjust the horizontal spacing between the plots, so the titles can be read.

# %%
plt.rc('figure', figsize=(10, 6))
plt.figure()
plt.subplot(2,1,1)
plt.plot(data['P75th'],'g--')
plt.title('Line Plot')

plt.figure()
plt.subplot(2,1,2)
plt.hist(data['Median'],bins=50)
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %% [markdown]
# #### 3. Create another figure that holds a 2x1 matrix of subplots.
# * In the first subplot, display a scatter plot comparing the `Unemployment_rate` column to the `Median` column and titled "Scatter Plot".
# * In the second subplot, display the density plot of the `ShareWomen` column that is  red and titled "Density Plot".
# * Adjust the horizontal spacing between the plots, so the titles can be read.

# %%
plt.rc('figure', figsize=(10, 6))
plt.figure()
plt.subplot(2,1,1)
plt.scatter(x=data['Unemployment_rate'],y=data['Median'])
plt.title('Scatter Plot')

plt.figure()
plt.subplot(2,1,2)
data['ShareWomen'].plot.density()
plt.title('Density Plot')
# Out:
# Text(0.5, 1.0, 'Density Plot')

# %% [markdown]
# #### 4. Create bar chart of majors with highest median incomes.
# * Create a new `DataFrame` called `top_medians` containing information about the majors with a median income over \\$60,000, sorted by median income.
# * Create a bar chart with the 25th quartile, median, and 75th quartile incomes for each major and titled 'Top Median Incomes'.

# %%
top_medians = data[data["Median"] > 60000].sort_values("Median")
top_medians.plot(x="Major", y=["P25th", "Median", "P75th"], kind="bar")
plt.title('Top Median Incomes')
# Out:
# Text(0.5, 1.0, 'Top Median Incomes')

# %% [markdown]
# #### 5. Create another bar chart with the same information above, but turned horizontally with the data stacked for each major and with the same title.

# %%
top_medians = data[data["Median"] > 60000].sort_values("Median")
top_medians.plot(x="Major", y=["P25th", "Median", "P75th"], kind="barh")
plt.title('Top Median Incomes')
# Out:
# Text(0.5, 1.0, 'Top Median Incomes')

# %% [markdown]
# #### 6. Create a histogram plot showing the distribution of the median earnings for all of the engineering majors with the title "Median Income for Engineering Majors" and colored red.

# %%
data[data["Major_category"] == "Engineering"]["Median"].plot(kind="hist",color='r')


plt.title('Median Income for Engineering Majors')
# Out:
# Text(0.5, 1.0, 'Median Income for Engineering Majors')

# %% [markdown]
# #### 7. Create a box plot showing the distribution of the median earnings for the  majors.
# * In one cell, display the first five entries in the `DataFrame`.
# * In another cell, display a box plot of the data with the title "Jobs Data".

# %%
top_medians.head()
# Out:
#       Major_code                                      Major    Total      Men  \
# Rank
# 7           6202                          ACTUARIAL SCIENCE   3777.0   2110.0
# 8           5001                 ASTRONOMY AND ASTROPHYSICS   1792.0    832.0
# 5           2405                       CHEMICAL ENGINEERING  32260.0  21239.0
# 6           2418                        NUCLEAR ENGINEERING   2573.0   2200.0
# 4           2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0   1123.0
#
#         Women     Major_category  ShareWomen  Sample_size  Employed  \
# Rank
# 7      1667.0           Business    0.441356           51      2912
# 8       960.0  Physical Sciences    0.535714           10      1526
# 5     11021.0        Engineering    0.341631          289     25694
# 6       373.0        Engineering    0.144967           17      1857
# 4       135.0        Engineering    0.107313           16       758
#
#       Full_time  Part_time  Full_time_year_round  Unemployed  \
# Rank
# ...

# %%
top_medians.plot(x="Major", y=["P25th", "Median", "P75th"], kind="pie")

plt.title("Jobs Data")
# Out:
# Text(0.5, 1.0, 'Jobs Data')

# %% [markdown]
# #### 8. Create a new `DataFrame` called `pair_data` with only the `Median`, `ShareWomen`, `Unemployment_rate`, and `College_jobs` data in the `data` DataFrame.
# * In one cell, display the first five entries in this `DataFrame`.
# * In another cell, create a pair plot and a display from the information in `pairplot` using the *seaborn* package functions with the title 'Pair Plot'.

# %%
pair_data = top_medians[['Median', 'ShareWomen', 'Unemployment_rate', 'College_jobs']].copy()
pair_data
# Out:
#       Median  ShareWomen  Unemployment_rate  College_jobs
# Rank
# 7      62000    0.441356           0.095652          1768
# 8      62000    0.535714           0.021167           972
# 5      65000    0.341631           0.061098         18314
# 6      65000    0.144967           0.177226          1142
# 4      70000    0.107313           0.050125           529
# 3      73000    0.153037           0.024096           456
# 2      75000    0.101852           0.117241           350
# 1     110000    0.120564           0.018381          1534

# %%
sns.pairplot(pair_data).set(title="Pair Plot")

# %% [markdown]
# #### 9. Group the information in `data` by its `Major_category`.
# * Find the average of the `ShareWomen` column in this grouping and create a `Series` object from this data with no name (i.e. `name=""`) called `pct_women`. Display its contents.
# * Display the results in a pie chart with the title "Women in Each Major".

# %%
pair_data['ShareWomen'].mean()
# Out:
# 0.243304262625

# %%
pct_women=pd.Series(pair_data['ShareWomen'], name="")

pct_women
# Out:
# Rank
# 7    0.441356
# 8    0.535714
# 5    0.341631
# 6    0.144967
# 4    0.107313
# 3    0.153037
# 2    0.101852
# 1    0.120564
# Name: , dtype: float64

# %%
pct_women.plot(kind='pie')
plt.title('Women in Each Major')
# Out:
# Text(0.5, 1.0, 'Women in Each Major')
