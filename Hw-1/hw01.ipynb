# %%
import pandas as pd

# %% [markdown]
# # NOAA Climate Datasets

# %%
data = pd.read_csv('01001599999.csv')

data
# Out:
#         STATION        DATE  LATITUDE  LONGITUDE  ELEVATION            NAME  \
# 0    1001599999  1995-01-01    61.383      5.867      327.0  BRINGELAND, NO
# 1    1001599999  1995-01-02    61.383      5.867      327.0  BRINGELAND, NO
# 2    1001599999  1995-01-03    61.383      5.867      327.0  BRINGELAND, NO
# 3    1001599999  1995-01-04    61.383      5.867      327.0  BRINGELAND, NO
# 4    1001599999  1995-01-05    61.383      5.867      327.0  BRINGELAND, NO
# ..          ...         ...       ...        ...        ...             ...
# 357  1001599999  1995-12-26    61.383      5.867      327.0  BRINGELAND, NO
# 358  1001599999  1995-12-27    61.383      5.867      327.0  BRINGELAND, NO
# 359  1001599999  1995-12-28    61.383      5.867      327.0  BRINGELAND, NO
# 360  1001599999  1995-12-29    61.383      5.867      327.0  BRINGELAND, NO
# 361  1001599999  1995-12-30    61.383      5.867      327.0  BRINGELAND, NO
#
# ...

# %% [raw]
# 1. How would you describe the data?
#
# - This a dataset in csv format for the use of National Centers for environmental research.
#
# 2. What is the data for?
#
# - For analysing to Global Surface Summary of the Day that taken into account a place called BRINGELAND.
#
# 3. How was the data collected?
#
# - The data was collected by observing the same station over the year of 1995.
#
#
# 4. What format is the data in?
#
# - csv.
#
# 5. Is the data up-to-date/recent?
#
# - No.
#
# 6. Is the data easily accessible?
#
# - Yes.
#
# 7. What restrictions are there on using the data?
#
# - No restrictions.
#
# 8. Can you think of something you could learn from analyzing this data?
#
# - Surface temparature changes throughout the year.
#
# 9. Can you think of some issues or challenges you might have if you analyzed this data? For instance, is the data too old? Is data missing?
#
# - The data is based on 1995, and thefore, not up-to-date. On top of that, it has only taken into account a single station. Therefore, it is hard to jump into any conclusion.

# %% [markdown]
# # CDC Data

# %%
df = pd.read_csv('COVID-19_Booster_Dose_Eligibility_in_the_United_States.csv')
df.head()
# Out:
#                      Date             Category Location  Booster_Eligible  \
# 0  02/16/2022 12:00:00 AM    Race_eth_Hispanic       US          21848243
# 1  02/16/2022 12:00:00 AM     Race_eth_NHWhite       US          78731931
# 2  02/16/2022 12:00:00 AM       Race_eth_known       US         129811279
# 3  02/16/2022 12:00:00 AM     Race_eth_unknown       US          41279304
# 4  02/16/2022 12:00:00 AM  Race_eth_NHMult_Oth       US           6163387
#
#    Booster_Eligible_NotBoosted  Booster_Eligible_Boosted_Pct  \
# 0                     13301339                          39.1
# 1                     35789346                          54.5
# 2                     63764713                          50.9
# 3                     21701995                          47.4
# 4                      3039240                          50.7
#
#    Booster_Eligible_NotBoosted_Pct  Booster_Eligible_US_Pct  \
# 0                             60.9                     12.8
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                       Date             Category Location  Booster_Eligible  \
# 0   02/16/2022 12:00:00 AM    Race_eth_Hispanic       US          21848243
# 1   02/16/2022 12:00:00 AM     Race_eth_NHWhite       US          78731931
# 2   02/16/2022 12:00:00 AM       Race_eth_known       US         129811279
# 3   02/16/2022 12:00:00 AM     Race_eth_unknown       US          41279304
# 4   02/16/2022 12:00:00 AM  Race_eth_NHMult_Oth       US           6163387
# 5   02/16/2022 12:00:00 AM      Race_eth_NHAIAN       US           1152245
# 6   02/16/2022 12:00:00 AM     Race_eth_NHNHOPI       US            420167
# 7   02/16/2022 12:00:00 AM     Race_eth_NHBlack       US          12428307
# 8   02/16/2022 12:00:00 AM     Total_Population       US         171090583
# 9   02/16/2022 12:00:00 AM     Race_eth_NHAsian       US           9066999
# 10  02/09/2022 12:00:00 AM     Total_Population       US         168848643
# ...

# %% [raw]
# 1. How would you describe the data?
#
# - This dataset has 50 rows and 18 columns that illustrates COvid-19 Booster Dose ability in the United States.
#
# 2. What is the data for?
#
# - This site provides historical data related to COVID-19 booster dose eligibility presented on two CDC COVID Data Tracker sites: Vaccinations in the US and Vaccination Equity.  Data are updated weekly on Wednesdays.
#
# 3. How was the data collected?
#
# - CDC counts people as having “received a booster dose” if they are fully vaccinated and received another dose of any COVID-19 vaccine on or after August 13, 2021. This does not distinguish whether the recipient is immunocompromised and received an additional dose.
#
#
# 4. What format is the data in?
#
# - csv.
#
# 5. Is the data up-to-date/recent?
#
# - Yes, very updated.
#
# 6. Is the data easily accessible?
#
# - Yes.
#
# 7. What restrictions are there on using the data?
#
# - No restrictions. It's publicly available for use.
#
# 8. Can you think of something you could learn from analyzing this data?
#
# -
# 9. Can you think of some issues or challenges you might have if you analyzed this data? For instance, is the data too old? Is data missing?
#
# - The booster eligibility metric excludes fully vaccinated recipients who have an “Other” primary series vaccine type.
# Booster eligibility counts and percentages exclude vaccine administrations reported by Texas as the primary series cannot be linked to booster dose in the aggregate data submitted by Texas.

# %% [markdown]
# #  California Open Portal Data

# %%
data = pd.read_csv('homeless_impact.csv')
data
# Out:
#                              county        date  rooms  rooms_occupied  \
# 0                     Tehama County  2022-02-17    NaN             NaN
# 1                  Del Norte County  2022-02-17   35.0            28.0
# 2                   Mariposa County  2022-02-17    NaN             NaN
# 3                     Fresno County  2022-02-17   27.0            26.0
# 4                  Calaveras County  2022-02-17   30.0            14.0
# ...                             ...         ...    ...             ...
# 17807                   Yolo County  2022-01-19   65.0            68.0
# 17808                   Yuba County  2022-01-19    NaN             NaN
# 17809        Wilton Rancheria Tribe  2022-01-19    NaN             NaN
# 17810  Bishop Paiute Tribal Council  2022-01-19    NaN             NaN
# 17811            Hoopa Valley Tribe  2022-01-19    NaN             NaN
#
#        trailers_requested  trailers_delivered  donated_trailers_delivered
# ...

# %%
data.describe()
# Out:
#               rooms  rooms_occupied  trailers_requested  trailers_delivered  \
# count  11837.000000    10567.000000         5822.000000         4532.000000
# mean     354.303286      259.778934           77.731364           80.757944
# std      735.664406      527.844885          136.711048          153.797207
# min       11.000000       11.000000           12.000000           12.000000
# 25%       51.000000       40.000000           15.000000           15.000000
# 50%      116.000000       87.000000           37.000000           28.000000
# 75%      305.000000      250.000000           91.000000           79.000000
# max     4697.000000     3942.000000          658.000000          654.000000
#
#        donated_trailers_delivered
# count                  527.000000
# mean                    16.508539
# std                      3.971311
# min                     12.000000
# 25%                     12.000000
# 50%                     20.000000
# 75%                     20.000000
# ...

# %% [raw]
# 1. How would you describe the data?
#
# - This dataset has 17812 rows and 7 columns that contain Covid-19 Homeless impact in US state of California.
#
# 2. What is the data for?
#
# - This dateset is for the use of California Department of Social Services.
#
# 3. How was the data collected?
#
# - DSS public relations collected the data since 4/14/2020 to present in a daily manner.
#
#
# 4. What format is the data in?
#
# - csv.
#
# 5. Is the data up-to-date/recent?
#
# - Yes, very updated.
#
# 6. Is the data easily accessible?
#
# - Yes.
#
# 7. What restrictions are there on using the data?
#
# - No restrictions. It's publicly available for use.
#
# 8. Can you think of something you could learn from analyzing this data?
#
# - rooms	rooms_occupied	trailers_requested	trailers_delivered	donated_trailers_delivered
# count	11837.000000	10567.000000	5822.000000	4532.000000	527.000000
# mean	354.303286	259.778934	77.731364	80.757944	16.508539
# std	   735.664406	527.844885	136.711048	153.797207	3.971311
# min	   11.000000	11.000000	12.000000	12.000000	12.000000
# 25%	   51.000000	40.000000	15.000000	15.000000	12.000000
# 50%	  116.000000	87.000000	37.000000	28.000000	20.000000
# 75%	  305.000000	250.000000	91.000000	79.000000	20.000000
# max	 4697.000000	3942.000000	658.000000	654.000000	20.000000
#
# 9. Can you think of some issues or challenges you might have if you analyzed this data? For instance, is the data too old? Is data missing?
#
# - Data missing is the most frequent problem in this dataset.

# %% [markdown]
# #  US Census Data

# %%
data = pd.read_csv ('GOVSTIMESERIES.GS00TC01_data_with_overlays_2022-02-20T024955.csv')

data
# Out:
#        GEO_ID      GEO_ID_F                  NAME  YEAR          SVY_COMP  \
# 0          id  Geo Footnote  Geographic Area Name  Year  Survey Component
# 1   0100000US           NaN         United States  2016                03
# 2   0100000US           NaN         United States  2017                03
# 3   0100000US           NaN         United States  2016                03
# 4   0100000US           NaN         United States  2017                03
# ..        ...           ...                   ...   ...               ...
# 58  0100000US           NaN         United States  2017                03
# 59  0100000US           NaN         United States  2016                03
# 60  0100000US           NaN         United States  2017                03
# 61  0100000US           NaN         United States  2016                03
# 62  0100000US           NaN         United States  2017                03
#
#                                       SVY_COMP_LABEL               AGG_DESC  \
# ...

# %%
data.describe()
# Out:
#            GEO_ID      GEO_ID_F           NAME  YEAR SVY_COMP  \
# count          63             1             63    63       63
# unique          2             1              2     3        2
# top     0100000US  Geo Footnote  United States  2017       03
# freq           62             1             62    31       62
#
#                                           SVY_COMP_LABEL AGG_DESC  \
# count                                                 63       63
# unique                                                 2       32
# top     Annual Survey of State Government Tax Collection   ST0T16
# freq                                                  62        2
#
#                   AGG_DESC_LABEL GOVTYPE GOVTYPE_LABEL   AMOUNT
# count                         63      63            63       63
# unique                        32       2             2       63
# top     Pari-mutuels Sales Taxes     002         State  1424462
# freq                           2      62            62        1

# %% [raw]
# 1. How would you describe the data?
#
# - This a dataset contains 63 rows and 11 columns to represent US tax collection detailed table that covers the United States, the 50 states, and the District of Columbia.
#
# 2. What is the data for?
#
# - This information represents public finance and public employment data for of the nation's state and local government sector.
#
# 3. How was the data collected?
#
# - Full-time and part-time employment, part-time hours worked, full-time equivalent employment, and payroll statistics by governmental function Taxes collected for state governments in the United States by category: Property Tax, Sales and Gross Receipts Taxes, License Taxes, Income Taxes, and Other Taxes Detail of revenue by source, expenditure by object and function, indebtedness by term, and assets by purpose, by state and by type.
#
#
# 4. What format is the data in?
#
# - csv.
#
# 5. Is the data up-to-date/recent?
#
# - No.
#
# 6. Is the data easily accessible?
#
# - Yes.
#
# 7. What restrictions are there on using the data?
#
# - No restrictions. It's publicly available for use.
#
# 8. Can you think of something you could learn from analyzing this data?
#
# - The highest amount of tax was collected back in 2017.
#
# 9. Can you think of some issues or challenges you might have if you analyzed this data? For instance, is the data too old? Is data missing?
# -  Thre is no major problem I found with this dataset.

# %% [markdown]
# # Twitter Datasets

# %%
data = pd.read_csv('Apple-Twitter-Sentiment-DFE.csv', encoding="ISO-8859-1")

data
# Out:
#        _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0     623495513     True      golden                  10               NaN
# 1     623495514     True      golden                  12               NaN
# 2     623495515     True      golden                  10               NaN
# 3     623495516     True      golden                  17               NaN
# 4     623495517    False   finalized                   3    12/12/14 12:14
# ...         ...      ...         ...                 ...               ...
# 3881  623499442     True      golden                  13               NaN
# 3882  623499450     True      golden                  16               NaN
# 3883  623499486     True      golden                  14               NaN
# 3884  623499514     True      golden                  13               NaN
# 3885  623517290     True      golden                  17               NaN
#
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0     623495513     True      golden                  10               NaN
# 1     623495514     True      golden                  12               NaN
# 2     623495515     True      golden                  10               NaN
# 3     623495516     True      golden                  17               NaN
# 4     623495517    False   finalized                   3    12/12/14 12:14
# ...         ...      ...         ...                 ...               ...
# 3881  623499442     True      golden                  13               NaN
# 3882  623499450     True      golden                  16               NaN
# 3883  623499486     True      golden                  14               NaN
# 3884  623499514     True      golden                  13               NaN
# 3885  623517290     True      golden                  17               NaN
#
# ...

# %%
data.describe()
# Out:
#            _unit_id  _trusted_judgments  sentiment:confidence            id
# count  3.886000e+03         3886.000000           3886.000000  3.886000e+03
# mean   6.234975e+08            3.687082              0.829526  5.410039e+17
# std    1.171906e+03            2.004595              0.175864  7.942752e+14
# min    6.234955e+08            3.000000              0.332700  5.400000e+17
# 25%    6.234965e+08            3.000000              0.674475  5.400000e+17
# 50%    6.234975e+08            3.000000              0.811250  5.410000e+17
# 75%    6.234984e+08            3.000000              1.000000  5.420000e+17
# max    6.235173e+08           27.000000              1.000000  5.420000e+17

# %% [raw]
# 1. How would you describe the data?
#
# - This a dataset in jason format to analyze twitter users' sentiment centaring apple.
#
# 2. What is the data for?
#
# - To look into the sentiment around Apple, based on tweets containing #AAPL, @apple, etc.   Contributors were given a tweet and asked whether the user was positive, negative, or neutral about Apple. (They were also allowed to mark "the tweet is not about the company Apple, Inc.)
#
# 3. How was the data collected?
#
# - The data was collected from the twitter.
#
#
# 4. What format is the data in?
#
# - csv.
#
# 5. Is the data up-to-date/recent?
#
# - No.
#
# 6. Is the data easily accessible?
#
# - Yes.
#
# 7. What restrictions are there on using the data?
#
# - No restrictions. It's publicly available for use.
#
# 8. Can you think of something you could learn from analyzing this data?
#
# - People expressed their sentiment overwhelmingly at night. And, all the tweets are on either Monday or Tuesday.
#
# 9. Can you think of some issues or challenges you might have if you analyzed this data? For instance, is the data too old? Is data missing?
#
# - The data is based on 2014, and thefore, not up-to-date. On top of that, there are frequent missing data in _last_judgment_at	and sentiment_gold column.
